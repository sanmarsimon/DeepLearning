# %% [markdown]
# # INF8225 Project - CNNs for image classification on CIFAR-10 and CIFAR-100 datasets
#
# We are going to analyze and compare the performances of the 4 following CNNs :
# - VGG-16
# - EfficientNetV2_M
# - EfficientNet-B0
# - ResNet-50
# - DenseNet121

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from torchvision import models
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Hyperparameters

# %%
num_epochs = 5
batch_size = 32
learning_rate = 0.001
momentum = 0.9
weight_decay=5e-4

# %% [markdown]
# # Datasets

# %%
transform = transforms.Compose([
    transforms.Resize(size=(224, 224)),
    transforms.ToTensor(),
    transforms.Normalize( 
       (0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010) 
    )
])

# %% [markdown]
# ## CIFAR-10

# %%
train_dataset_10 = torchvision.datasets.CIFAR10(
    root= './data', train = True,
    download =True, transform = transform)
test_dataset_10 = torchvision.datasets.CIFAR10(
    root= './data', train = False,
    download =True, transform = transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
len_train = int(len(train_dataset_10) * 0.9)
len_val = len(train_dataset_10) - len_train
train_subset, val_subset = random_split(train_dataset_10, [len_train, len_val])

# %%
train_loader_10 = torch.utils.data.DataLoader(train_subset
    , batch_size = batch_size
    , shuffle = True)
val_loader_10 = torch.utils.data.DataLoader(val_subset
    , batch_size = batch_size
    , shuffle = True)
test_loader_10 = torch.utils.data.DataLoader(test_dataset_10
    , batch_size = batch_size
    , shuffle = True)
n_total_step = len(train_loader_10)
print(n_total_step)
# Out:
# 1407

# %%
print(len(val_loader_10))
# Out:
# 157

# %% [markdown]
# ## CIFAR-100

# %%
train_dataset_100 = torchvision.datasets.CIFAR100(
    root= './data', train = True,
    download =True, transform = transform)
test_dataset_100 = torchvision.datasets.CIFAR100(
    root= './data', train = False,
    download =True, transform = transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
len_train = int(len(train_dataset_100) * 0.9)
len_val = len(train_dataset_100) - len_train
train_subset, val_subset = random_split(train_dataset_100, [len_train, len_val])

# %%
train_loader_100 = torch.utils.data.DataLoader(train_subset
    , batch_size = batch_size
    , shuffle = True)
val_loader_100 = torch.utils.data.DataLoader(val_subset
    , batch_size = batch_size
    , shuffle = True)
test_loader_100 = torch.utils.data.DataLoader(test_dataset_100
    , batch_size = batch_size
    , shuffle = True)
n_total_step = len(train_loader_100)
print(n_total_step)
# Out:
# 1407

# %% [markdown]
# # Load pre-trained models

# %% [markdown]
# ## VGG-16

# %%
vgg16_10 = models.vgg16(pretrained = True)
input_lastLayer = vgg16_10.classifier[6].in_features
vgg16_10.classifier[6] = nn.Linear(input_lastLayer,10)
vgg16_10 = vgg16_10.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Last layer with 100 outputs (because CIFAR-100)
vgg16_100 = models.vgg16(pretrained = True)
input_lastLayer = vgg16_100.classifier[6].in_features
vgg16_100.classifier[6] = nn.Linear(input_lastLayer,100)
vgg16_100 = vgg16_100.to(device)

# %% [markdown]
# ## EfficientNetV2_M

# %%
effnet_v2_10 = models.efficientnet_v2_m(pretrained = True)
input_lastLayer = effnet_v2_10.classifier[1].in_features
effnet_v2_10.classifier[1] = nn.Linear(input_lastLayer,10)
effnet_v2_10 = effnet_v2_10.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_V2_M_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_V2_M_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Last layer with 100 outputs (because CIFAR-100)
effnet_v2_100 = models.efficientnet_v2_m(pretrained = True)
input_lastLayer = effnet_v2_100.classifier[1].in_features
effnet_v2_100.classifier[1] = nn.Linear(input_lastLayer,100)
effnet_v2_100 = effnet_v2_100.to(device)

# %% [markdown]
# ## EfficientNet-B0

# %%
effnet_10 = models.efficientnet_b0(pretrained = True)
input_lastLayer = effnet_10.classifier[1].in_features
effnet_10.classifier[1] = nn.Linear(input_lastLayer,10)
effnet_10 = effnet_10.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Last layer with 100 outputs (because CIFAR-100)
effnet_100 = models.efficientnet_b0(pretrained = True)
input_lastLayer = effnet_100.classifier[1].in_features
effnet_100.classifier[1] = nn.Linear(input_lastLayer,100)
effnet_100 = effnet_100.to(device)

# %% [markdown]
# ## ResNet-50

# %%
res50_10 = models.resnet50(pretrained = True)
input_lastLayer = res50_10.fc.in_features
res50_10.fc = nn.Linear(input_lastLayer,10)
res50_10 = res50_10.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Last layer with 100 outputs (because CIFAR-100)
res50_100 = models.resnet50(pretrained = True)
input_lastLayer = res50_100.fc.in_features
res50_100.fc = nn.Linear(input_lastLayer,100)
res50_100 = res50_100.to(device)

# %% [markdown]
# ## Densenet-121

# %%
dense121_10 = models.densenet121(pretrained = True)
input_lastLayer = dense121_10.classifier.in_features
dense121_10.classifier = nn.Linear(input_lastLayer,10)
dense121_10 = dense121_10.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Last layer with 100 outputs (because CIFAR-100)
dense121_100 = models.densenet121(pretrained = True)
input_lastLayer = dense121_100.classifier.in_features
dense121_100.classifier = nn.Linear(input_lastLayer,100)
dense121_100 = dense121_100.to(device)

# %% [markdown]
# # Train the models

# %%
criterion=nn.CrossEntropyLoss()

# %%
def train(model, train_dataloader, val_dataloader):
  losses_train = []
  accuracies_train = []
  losses_val = []
  accuracies_val = []

  best_model = model
  best_val_accuracy = 0.0

  n_total_step = len(train_dataloader)

  optimizer = torch.optim.SGD(model.parameters(), 
                              lr = learning_rate, 
                              momentum=momentum,
                              weight_decay=weight_decay
                              )

  for epoch in range(num_epochs):
    ######################## TRAINING #############################
    train_loss = 0.0
    train_total_preds = 0
    train_total_corrects = 0
    model.train()

    for i, (imgs , labels) in enumerate(train_dataloader):
      imgs = imgs.to(device)
      labels = labels.to(device)
      labels_hat = model(imgs)
      n_corrects = (labels_hat.argmax(axis=1)==labels).sum().item()
      loss_value = criterion(labels_hat, labels)
      train_loss += loss_value.item()
      train_total_corrects += n_corrects
      train_total_preds += labels.size(0)
      loss_value.backward()
      optimizer.step()
      optimizer.zero_grad()
      if (i+1) % 250 == 0:
        print(f'epoch {epoch+1}/{num_epochs}, step: {i+1}/{n_total_step}: Training loss = {loss_value:.5f}, Training acc = {100*(n_corrects/labels.size(0)):.2f}%')
    print()

    ####################### VALIDATION ##############################
    val_loss = 0.0
    val_total_preds = 0
    val_total_corrects = 0
    model.eval()

    for imgs, labels in val_dataloader:
      imgs = imgs.to(device)
      labels = labels.to(device)
      labels_hat = model(imgs)
      n_corrects = (labels_hat.argmax(axis=1)==labels).sum().item()
      loss_value = criterion(labels_hat, labels)
      val_loss += loss_value.item()
      val_total_corrects += n_corrects
      val_total_preds += labels.size(0)

    accuracy_train = 100*(train_total_corrects/train_total_preds)
    accuracy_val = 100*(val_total_corrects/val_total_preds)
    if accuracy_val > best_val_accuracy:
      best_val_accuracy = accuracy_val
      best_model = model

    print(f"Epoch {epoch+1:2d}, \
                Train: loss={(train_loss / len(train_dataloader)):.3f}, accuracy={accuracy_train:.1f}%, \
                Valid: loss={(val_loss / len(val_dataloader)):.3f}, accuracy={accuracy_val:.1f}%", flush=True)
    
    print()
    losses_train.append(train_loss / len(train_dataloader))
    losses_val.append(val_loss / len(val_dataloader))
    accuracies_train.append(accuracy_train)
    accuracies_val.append(accuracy_val)

  return best_model, losses_train, losses_val, accuracies_train, accuracies_val

# %%
def plot_loss_and_accuracy(train_losses, val_losses, train_acc, val_acc):
  fig = plt.figure(figsize=(10,5))
  ax0 = fig.add_subplot(121, title="Training and Validation Loss")
  ax1 = fig.add_subplot(122, title="Training and Validation Accuracy")
  # plt.title("Training and Validation Loss")
  ax0.plot(val_losses,label="val")
  ax0.plot(train_losses,label="train")
  ax0.set_xlabel("Epoch")
  ax0.set_ylabel("Loss")
  ax0.legend()

  ax1.plot(val_acc,label="val")
  ax1.plot(train_acc,label="train")
  ax1.set_xlabel("Epoch")
  ax1.set_ylabel("Accuracy")
  ax1.legend()

  fig.show()

# %% [markdown]
# ## VGG-16

# %% [markdown]
# ### CIFAR-10

# %%
vgg16_10, train_loss, val_loss, train_acc, val_acc = train(vgg16_10, train_loader_10, val_loader_10)
# Out:
# epoch 1/5, step: 250/1407: Training loss = 0.28635, Training acc = 90.62%
# epoch 1/5, step: 500/1407: Training loss = 0.49942, Training acc = 84.38%
# epoch 1/5, step: 750/1407: Training loss = 0.45224, Training acc = 87.50%
# epoch 1/5, step: 1000/1407: Training loss = 0.59582, Training acc = 78.12%
# epoch 1/5, step: 1250/1407: Training loss = 0.31312, Training acc = 93.75%
#
# Epoch  1,                 Train: loss=0.448, accuracy=84.7%,                 Valid: loss=0.277, accuracy=90.5%
#
# epoch 2/5, step: 250/1407: Training loss = 0.20333, Training acc = 93.75%
# epoch 2/5, step: 500/1407: Training loss = 0.17082, Training acc = 87.50%
# epoch 2/5, step: 750/1407: Training loss = 0.19947, Training acc = 96.88%
# epoch 2/5, step: 1000/1407: Training loss = 0.54872, Training acc = 90.62%
# epoch 2/5, step: 1250/1407: Training loss = 0.13483, Training acc = 93.75%
#
# Epoch  2,                 Train: loss=0.222, accuracy=92.5%,                 Valid: loss=0.246, accuracy=91.8%
#
# epoch 3/5, step: 250/1407: Training loss = 0.02311, Training acc = 100.00%
# epoch 3/5, step: 500/1407: Training loss = 0.06093, Training acc = 96.88%
# epoch 3/5, step: 750/1407: Training loss = 0.07865, Training acc = 96.88%
# epoch 3/5, step: 1000/1407: Training loss = 0.42958, Training acc = 84.38%
# epoch 3/5, step: 1250/1407: Training loss = 0.15744, Training acc = 96.88%
#
# Epoch  3,                 Train: loss=0.139, accuracy=95.1%,                 Valid: loss=0.213, accuracy=92.9%
#
# epoch 4/5, step: 250/1407: Training loss = 0.09848, Training acc = 96.88%
# epoch 4/5, step: 500/1407: Training loss = 0.03024, Training acc = 100.00%
# epoch 4/5, step: 750/1407: Training loss = 0.05069, Training acc = 96.88%
# epoch 4/5, step: 1000/1407: Training loss = 0.03795, Training acc = 96.88%
# epoch 4/5, step: 1250/1407: Training loss = 0.02432, Training acc = 100.00%
#
# Epoch  4,                 Train: loss=0.093, accuracy=96.8%,                 Valid: loss=0.216, accuracy=93.4%
#
# epoch 5/5, step: 250/1407: Training loss = 0.02844, Training acc = 100.00%
# epoch 5/5, step: 500/1407: Training loss = 0.00364, Training acc = 100.00%
# epoch 5/5, step: 750/1407: Training loss = 0.06519, Training acc = 93.75%
# epoch 5/5, step: 1000/1407: Training loss = 0.19124, Training acc = 93.75%
# epoch 5/5, step: 1250/1407: Training loss = 0.04984, Training acc = 100.00%
#
# Epoch  5,                 Train: loss=0.062, accuracy=97.8%,                 Valid: loss=0.245, accuracy=92.5%

# %%
plot_loss_and_accuracy(train_loss, val_loss, train_acc, val_acc)

# %% [markdown]
# ### CIFAR-100

# %%
vgg16_100, train_loss, val_loss, train_acc, val_acc = train(vgg16_100, train_loader_100, val_loader_100)
# Out:
# epoch 1/5, step: 250/1407: Training loss = 1.62481, Training acc = 59.38%
# epoch 1/5, step: 500/1407: Training loss = 2.10142, Training acc = 40.62%
# epoch 1/5, step: 750/1407: Training loss = 1.44763, Training acc = 62.50%
# epoch 1/5, step: 1000/1407: Training loss = 1.50832, Training acc = 59.38%
# epoch 1/5, step: 1250/1407: Training loss = 1.20071, Training acc = 68.75%
#
# Epoch  1,                 Train: loss=1.802, accuracy=51.4%,                 Valid: loss=1.125, accuracy=67.8%
#
# epoch 2/5, step: 250/1407: Training loss = 0.90757, Training acc = 75.00%
# epoch 2/5, step: 500/1407: Training loss = 1.31725, Training acc = 59.38%
# epoch 2/5, step: 750/1407: Training loss = 1.92015, Training acc = 53.12%
# epoch 2/5, step: 1000/1407: Training loss = 1.18554, Training acc = 53.12%
# epoch 2/5, step: 1250/1407: Training loss = 1.09763, Training acc = 78.12%
#
# Epoch  2,                 Train: loss=1.051, accuracy=68.9%,                 Valid: loss=0.986, accuracy=70.6%
#
# epoch 3/5, step: 250/1407: Training loss = 1.39873, Training acc = 68.75%
# epoch 3/5, step: 500/1407: Training loss = 0.62786, Training acc = 84.38%
# epoch 3/5, step: 750/1407: Training loss = 0.61441, Training acc = 75.00%
# epoch 3/5, step: 1000/1407: Training loss = 0.60528, Training acc = 81.25%
# epoch 3/5, step: 1250/1407: Training loss = 0.52443, Training acc = 87.50%
#
# Epoch  3,                 Train: loss=0.778, accuracy=76.3%,                 Valid: loss=0.911, accuracy=73.1%
#
# epoch 4/5, step: 250/1407: Training loss = 0.55182, Training acc = 81.25%
# epoch 4/5, step: 500/1407: Training loss = 0.62222, Training acc = 78.12%
# epoch 4/5, step: 750/1407: Training loss = 0.37742, Training acc = 93.75%
# epoch 4/5, step: 1000/1407: Training loss = 0.38799, Training acc = 90.62%
# epoch 4/5, step: 1250/1407: Training loss = 1.28756, Training acc = 62.50%
#
# Epoch  4,                 Train: loss=0.587, accuracy=81.5%,                 Valid: loss=0.924, accuracy=73.2%
#
# epoch 5/5, step: 250/1407: Training loss = 0.47190, Training acc = 84.38%
# epoch 5/5, step: 500/1407: Training loss = 0.41304, Training acc = 87.50%
# epoch 5/5, step: 750/1407: Training loss = 0.38744, Training acc = 90.62%
# epoch 5/5, step: 1000/1407: Training loss = 0.44985, Training acc = 78.12%
# epoch 5/5, step: 1250/1407: Training loss = 0.44767, Training acc = 81.25%
#
# Epoch  5,                 Train: loss=0.448, accuracy=85.4%,                 Valid: loss=0.883, accuracy=74.5%

# %%
plot_loss_and_accuracy(train_loss, val_loss, train_acc, val_acc)

# %% [markdown]
# ## EfficientNetV2_M

# %% [markdown]
# ### CIFAR-10

# %%
effnet_v2_10, train_loss, val_loss, train_acc, val_acc = train(effnet_v2_10, train_loader_10, val_loader_10)
# Out:
# epoch 1/5, step: 250/1407: Training loss = 0.40199, Training acc = 90.62%
# epoch 1/5, step: 500/1407: Training loss = 0.11319, Training acc = 96.88%
# epoch 1/5, step: 750/1407: Training loss = 0.15037, Training acc = 90.62%
# epoch 1/5, step: 1000/1407: Training loss = 0.02749, Training acc = 100.00%
# epoch 1/5, step: 1250/1407: Training loss = 0.22619, Training acc = 90.62%
#
# Epoch  1,                 Train: loss=0.326, accuracy=90.3%,                 Valid: loss=0.096, accuracy=96.9%
#
# epoch 2/5, step: 250/1407: Training loss = 0.02120, Training acc = 100.00%
# epoch 2/5, step: 500/1407: Training loss = 0.01687, Training acc = 100.00%
# epoch 2/5, step: 750/1407: Training loss = 0.12099, Training acc = 96.88%
# epoch 2/5, step: 1000/1407: Training loss = 0.02740, Training acc = 100.00%
# epoch 2/5, step: 1250/1407: Training loss = 0.06805, Training acc = 96.88%
#
# Epoch  2,                 Train: loss=0.075, accuracy=97.6%,                 Valid: loss=0.086, accuracy=97.1%
#
# epoch 3/5, step: 250/1407: Training loss = 0.02406, Training acc = 100.00%
# epoch 3/5, step: 500/1407: Training loss = 0.01097, Training acc = 100.00%
# epoch 3/5, step: 750/1407: Training loss = 0.00409, Training acc = 100.00%
# epoch 3/5, step: 1000/1407: Training loss = 0.01265, Training acc = 100.00%
# epoch 3/5, step: 1250/1407: Training loss = 0.04606, Training acc = 96.88%
#
# Epoch  3,                 Train: loss=0.035, accuracy=98.9%,                 Valid: loss=0.077, accuracy=97.5%
#
# epoch 4/5, step: 250/1407: Training loss = 0.00644, Training acc = 100.00%
# epoch 4/5, step: 500/1407: Training loss = 0.08310, Training acc = 96.88%
# epoch 4/5, step: 750/1407: Training loss = 0.00181, Training acc = 100.00%
# epoch 4/5, step: 1000/1407: Training loss = 0.00130, Training acc = 100.00%
# epoch 4/5, step: 1250/1407: Training loss = 0.00036, Training acc = 100.00%
#
# Epoch  4,                 Train: loss=0.019, accuracy=99.4%,                 Valid: loss=0.084, accuracy=97.7%
#
# epoch 5/5, step: 250/1407: Training loss = 0.00225, Training acc = 100.00%
# epoch 5/5, step: 500/1407: Training loss = 0.00070, Training acc = 100.00%
# epoch 5/5, step: 750/1407: Training loss = 0.00329, Training acc = 100.00%
# epoch 5/5, step: 1000/1407: Training loss = 0.00193, Training acc = 100.00%
# epoch 5/5, step: 1250/1407: Training loss = 0.02266, Training acc = 100.00%
#
# Epoch  5,                 Train: loss=0.013, accuracy=99.6%,                 Valid: loss=0.083, accuracy=97.7%

# %%
plot_loss_and_accuracy(train_loss, val_loss, train_acc, val_acc)

# %% [markdown]
# ### CIFAR-100

# %%
effnet_v2_100, train_loss, val_loss, train_acc, val_acc = train(effnet_v2_100, train_loader_100, val_loader_100)
# Out:
# epoch 1/5, step: 250/1407: Training loss = 4.07483, Training acc = 15.62%
# epoch 1/5, step: 500/1407: Training loss = 1.06728, Training acc = 75.00%
# epoch 1/5, step: 750/1407: Training loss = 0.73666, Training acc = 84.38%
# epoch 1/5, step: 1000/1407: Training loss = 0.80418, Training acc = 87.50%
# epoch 1/5, step: 1250/1407: Training loss = 0.48465, Training acc = 84.38%
#
# Epoch  1,                 Train: loss=1.810, accuracy=57.0%,                 Valid: loss=0.553, accuracy=83.0%
#
# epoch 2/5, step: 250/1407: Training loss = 0.52035, Training acc = 81.25%
# epoch 2/5, step: 500/1407: Training loss = 0.74707, Training acc = 78.12%
# epoch 2/5, step: 750/1407: Training loss = 0.41863, Training acc = 78.12%
# epoch 2/5, step: 1000/1407: Training loss = 0.40829, Training acc = 81.25%
# epoch 2/5, step: 1250/1407: Training loss = 0.62278, Training acc = 84.38%
#
# Epoch  2,                 Train: loss=0.494, accuracy=84.8%,                 Valid: loss=0.442, accuracy=86.5%
#
# epoch 3/5, step: 250/1407: Training loss = 0.20559, Training acc = 93.75%
# epoch 3/5, step: 500/1407: Training loss = 0.22124, Training acc = 93.75%
# epoch 3/5, step: 750/1407: Training loss = 0.19109, Training acc = 93.75%
# epoch 3/5, step: 1000/1407: Training loss = 0.15692, Training acc = 93.75%
# epoch 3/5, step: 1250/1407: Training loss = 0.38876, Training acc = 87.50%
#
# Epoch  3,                 Train: loss=0.288, accuracy=91.0%,                 Valid: loss=0.407, accuracy=87.9%
#
# epoch 4/5, step: 250/1407: Training loss = 0.26891, Training acc = 90.62%
# epoch 4/5, step: 500/1407: Training loss = 0.24884, Training acc = 93.75%
# epoch 4/5, step: 750/1407: Training loss = 0.17304, Training acc = 93.75%
# epoch 4/5, step: 1000/1407: Training loss = 0.20499, Training acc = 93.75%
# epoch 4/5, step: 1250/1407: Training loss = 0.15643, Training acc = 96.88%
#
# Epoch  4,                 Train: loss=0.187, accuracy=94.0%,                 Valid: loss=0.408, accuracy=88.4%
#
# epoch 5/5, step: 250/1407: Training loss = 0.10482, Training acc = 96.88%
# epoch 5/5, step: 500/1407: Training loss = 0.34067, Training acc = 90.62%
# epoch 5/5, step: 750/1407: Training loss = 0.02808, Training acc = 100.00%
# epoch 5/5, step: 1000/1407: Training loss = 0.12700, Training acc = 96.88%
# epoch 5/5, step: 1250/1407: Training loss = 0.02497, Training acc = 100.00%
#
# Epoch  5,                 Train: loss=0.131, accuracy=95.9%,                 Valid: loss=0.427, accuracy=88.2%

# %%
plot_loss_and_accuracy(train_loss, val_loss, train_acc, val_acc)

# %% [markdown]
# ## EfficientNet-B0

# %% [markdown]
# ### CIFAR-10

# %%
effnet_10, train_loss, val_loss, train_acc, val_acc = train(effnet_10, train_loader_10, val_loader_10)
# Out:
# epoch 1/5, step: 250/1407: Training loss = 0.89572, Training acc = 75.00%
# epoch 1/5, step: 500/1407: Training loss = 0.49708, Training acc = 87.50%
# epoch 1/5, step: 750/1407: Training loss = 0.51638, Training acc = 81.25%
# epoch 1/5, step: 1000/1407: Training loss = 0.19925, Training acc = 93.75%
# epoch 1/5, step: 1250/1407: Training loss = 0.21361, Training acc = 93.75%
#
# Epoch  1,                 Train: loss=0.693, accuracy=79.5%,                 Valid: loss=0.235, accuracy=92.4%
#
# epoch 2/5, step: 250/1407: Training loss = 0.20259, Training acc = 93.75%
# epoch 2/5, step: 500/1407: Training loss = 0.22962, Training acc = 90.62%
# epoch 2/5, step: 750/1407: Training loss = 0.28145, Training acc = 96.88%
# epoch 2/5, step: 1000/1407: Training loss = 0.46212, Training acc = 87.50%
# epoch 2/5, step: 1250/1407: Training loss = 0.20628, Training acc = 96.88%
#
# Epoch  2,                 Train: loss=0.263, accuracy=91.3%,                 Valid: loss=0.169, accuracy=94.4%
#
# epoch 3/5, step: 250/1407: Training loss = 0.11129, Training acc = 93.75%
# epoch 3/5, step: 500/1407: Training loss = 0.06368, Training acc = 100.00%
# epoch 3/5, step: 750/1407: Training loss = 0.17058, Training acc = 90.62%
# epoch 3/5, step: 1000/1407: Training loss = 0.07434, Training acc = 100.00%
# epoch 3/5, step: 1250/1407: Training loss = 0.04706, Training acc = 100.00%
#
# Epoch  3,                 Train: loss=0.190, accuracy=93.8%,                 Valid: loss=0.147, accuracy=95.1%
#
# epoch 4/5, step: 250/1407: Training loss = 0.20213, Training acc = 93.75%
# epoch 4/5, step: 500/1407: Training loss = 0.26755, Training acc = 90.62%
# epoch 4/5, step: 750/1407: Training loss = 0.15867, Training acc = 96.88%
# epoch 4/5, step: 1000/1407: Training loss = 0.12465, Training acc = 96.88%
# epoch 4/5, step: 1250/1407: Training loss = 0.18108, Training acc = 90.62%
#
# Epoch  4,                 Train: loss=0.146, accuracy=95.1%,                 Valid: loss=0.129, accuracy=95.9%
#
# epoch 5/5, step: 250/1407: Training loss = 0.11949, Training acc = 93.75%
# epoch 5/5, step: 500/1407: Training loss = 0.08626, Training acc = 96.88%
# epoch 5/5, step: 750/1407: Training loss = 0.17660, Training acc = 93.75%
# epoch 5/5, step: 1000/1407: Training loss = 0.08598, Training acc = 96.88%
# epoch 5/5, step: 1250/1407: Training loss = 0.04298, Training acc = 100.00%
#
# Epoch  5,                 Train: loss=0.120, accuracy=96.0%,                 Valid: loss=0.120, accuracy=95.9%

# %%
plot_loss_and_accuracy(train_loss, val_loss, train_acc, val_acc)

# %% [markdown]
# ### CIFAR-100

# %%
effnet_100, train_loss, val_loss, train_acc, val_acc = train(effnet_100, train_loader_100, val_loader_100)
# Out:
# epoch 1/5, step: 250/1407: Training loss = 4.31672, Training acc = 6.25%
# epoch 1/5, step: 500/1407: Training loss = 3.76599, Training acc = 28.12%
# epoch 1/5, step: 750/1407: Training loss = 2.89110, Training acc = 43.75%
# epoch 1/5, step: 1000/1407: Training loss = 2.57033, Training acc = 40.62%
# epoch 1/5, step: 1250/1407: Training loss = 1.97404, Training acc = 56.25%
#
# Epoch  1,                 Train: loss=3.167, accuracy=35.3%,                 Valid: loss=1.460, accuracy=65.2%
#
# epoch 2/5, step: 250/1407: Training loss = 1.40057, Training acc = 68.75%
# epoch 2/5, step: 500/1407: Training loss = 1.15829, Training acc = 75.00%
# epoch 2/5, step: 750/1407: Training loss = 1.30313, Training acc = 65.62%
# epoch 2/5, step: 1000/1407: Training loss = 0.98309, Training acc = 68.75%
# epoch 2/5, step: 1250/1407: Training loss = 1.03768, Training acc = 68.75%
#
# Epoch  2,                 Train: loss=1.284, accuracy=66.1%,                 Valid: loss=0.867, accuracy=75.4%
#
# epoch 3/5, step: 250/1407: Training loss = 0.59362, Training acc = 78.12%
# epoch 3/5, step: 500/1407: Training loss = 1.23742, Training acc = 65.62%
# epoch 3/5, step: 750/1407: Training loss = 1.37180, Training acc = 62.50%
# epoch 3/5, step: 1000/1407: Training loss = 1.00677, Training acc = 71.88%
# epoch 3/5, step: 1250/1407: Training loss = 0.82345, Training acc = 78.12%
#
# Epoch  3,                 Train: loss=0.920, accuracy=73.8%,                 Valid: loss=0.699, accuracy=79.2%
#
# epoch 4/5, step: 250/1407: Training loss = 0.60287, Training acc = 87.50%
# epoch 4/5, step: 500/1407: Training loss = 0.74596, Training acc = 75.00%
# epoch 4/5, step: 750/1407: Training loss = 0.88151, Training acc = 78.12%
# epoch 4/5, step: 1000/1407: Training loss = 0.84827, Training acc = 75.00%
# epoch 4/5, step: 1250/1407: Training loss = 0.87740, Training acc = 75.00%
#
# Epoch  4,                 Train: loss=0.748, accuracy=77.9%,                 Valid: loss=0.626, accuracy=80.9%
#
# epoch 5/5, step: 250/1407: Training loss = 0.64382, Training acc = 78.12%
# epoch 5/5, step: 500/1407: Training loss = 0.82372, Training acc = 75.00%
# epoch 5/5, step: 750/1407: Training loss = 0.45369, Training acc = 84.38%
# epoch 5/5, step: 1000/1407: Training loss = 0.62540, Training acc = 71.88%
# epoch 5/5, step: 1250/1407: Training loss = 0.78374, Training acc = 81.25%
#
# Epoch  5,                 Train: loss=0.637, accuracy=81.1%,                 Valid: loss=0.590, accuracy=81.8%

# %%
plot_loss_and_accuracy(train_loss, val_loss, train_acc, val_acc)

# %% [markdown]
# ## ResNet-50

# %% [markdown]
# ### CIFAR-10

# %%
res50_10, train_loss, val_loss, train_acc, val_acc = train(res50_10, train_loader_10, val_loader_10)
# Out:
# epoch 1/5, step: 250/1407: Training loss = 0.41094, Training acc = 84.38%
# epoch 1/5, step: 500/1407: Training loss = 0.29952, Training acc = 90.62%
# epoch 1/5, step: 750/1407: Training loss = 0.30250, Training acc = 87.50%
# epoch 1/5, step: 1000/1407: Training loss = 0.20160, Training acc = 90.62%
# epoch 1/5, step: 1250/1407: Training loss = 0.17961, Training acc = 93.75%
#
# Epoch  1,                 Train: loss=0.343, accuracy=89.1%,                 Valid: loss=0.151, accuracy=94.8%
#
# epoch 2/5, step: 250/1407: Training loss = 0.04736, Training acc = 100.00%
# epoch 2/5, step: 500/1407: Training loss = 0.08704, Training acc = 93.75%
# epoch 2/5, step: 750/1407: Training loss = 0.02263, Training acc = 100.00%
# epoch 2/5, step: 1000/1407: Training loss = 0.10855, Training acc = 93.75%
# epoch 2/5, step: 1250/1407: Training loss = 0.23952, Training acc = 90.62%
#
# Epoch  2,                 Train: loss=0.107, accuracy=96.5%,                 Valid: loss=0.118, accuracy=96.1%
#
# epoch 3/5, step: 250/1407: Training loss = 0.01248, Training acc = 100.00%
# epoch 3/5, step: 500/1407: Training loss = 0.01025, Training acc = 100.00%
# epoch 3/5, step: 750/1407: Training loss = 0.01498, Training acc = 100.00%
# epoch 3/5, step: 1000/1407: Training loss = 0.07773, Training acc = 96.88%
# epoch 3/5, step: 1250/1407: Training loss = 0.19660, Training acc = 90.62%
#
# Epoch  3,                 Train: loss=0.049, accuracy=98.4%,                 Valid: loss=0.136, accuracy=95.9%
#
# epoch 4/5, step: 250/1407: Training loss = 0.01517, Training acc = 100.00%
# epoch 4/5, step: 500/1407: Training loss = 0.00860, Training acc = 100.00%
# epoch 4/5, step: 750/1407: Training loss = 0.04177, Training acc = 100.00%
# epoch 4/5, step: 1000/1407: Training loss = 0.01642, Training acc = 100.00%
# epoch 4/5, step: 1250/1407: Training loss = 0.01340, Training acc = 100.00%
#
# Epoch  4,                 Train: loss=0.029, accuracy=99.2%,                 Valid: loss=0.127, accuracy=96.2%
#
# epoch 5/5, step: 250/1407: Training loss = 0.00492, Training acc = 100.00%
# epoch 5/5, step: 500/1407: Training loss = 0.01787, Training acc = 100.00%
# epoch 5/5, step: 750/1407: Training loss = 0.00462, Training acc = 100.00%
# epoch 5/5, step: 1000/1407: Training loss = 0.01201, Training acc = 100.00%
# epoch 5/5, step: 1250/1407: Training loss = 0.01231, Training acc = 100.00%
#
# Epoch  5,                 Train: loss=0.018, accuracy=99.5%,                 Valid: loss=0.123, accuracy=96.5%

# %%
plot_loss_and_accuracy(train_loss, val_loss, train_acc, val_acc)

# %% [markdown]
# ### CIFAR-100

# %%
res50_100, train_loss, val_loss, train_acc, val_acc = train(res50_100, train_loader_100, val_loader_100)
# Out:
# epoch 1/5, step: 250/1407: Training loss = 2.80169, Training acc = 43.75%
# epoch 1/5, step: 500/1407: Training loss = 1.75396, Training acc = 56.25%
# epoch 1/5, step: 750/1407: Training loss = 1.29157, Training acc = 68.75%
# epoch 1/5, step: 1000/1407: Training loss = 1.04982, Training acc = 71.88%
# epoch 1/5, step: 1250/1407: Training loss = 0.90263, Training acc = 68.75%
#
# Epoch  1,                 Train: loss=1.779, accuracy=57.7%,                 Valid: loss=0.785, accuracy=76.2%
#
# epoch 2/5, step: 250/1407: Training loss = 0.69005, Training acc = 81.25%
# epoch 2/5, step: 500/1407: Training loss = 0.82285, Training acc = 75.00%
# epoch 2/5, step: 750/1407: Training loss = 0.50155, Training acc = 81.25%
# epoch 2/5, step: 1000/1407: Training loss = 0.48633, Training acc = 87.50%
# epoch 2/5, step: 1250/1407: Training loss = 0.76864, Training acc = 75.00%
#
# Epoch  2,                 Train: loss=0.679, accuracy=80.3%,                 Valid: loss=0.627, accuracy=80.8%
#
# epoch 3/5, step: 250/1407: Training loss = 0.34862, Training acc = 90.62%
# epoch 3/5, step: 500/1407: Training loss = 0.39543, Training acc = 81.25%
# epoch 3/5, step: 750/1407: Training loss = 0.35821, Training acc = 81.25%
# epoch 3/5, step: 1000/1407: Training loss = 0.35843, Training acc = 84.38%
# epoch 3/5, step: 1250/1407: Training loss = 0.29282, Training acc = 87.50%
#
# Epoch  3,                 Train: loss=0.428, accuracy=87.4%,                 Valid: loss=0.582, accuracy=82.5%
#
# epoch 4/5, step: 250/1407: Training loss = 0.46138, Training acc = 84.38%
# epoch 4/5, step: 500/1407: Training loss = 0.31123, Training acc = 90.62%
# epoch 4/5, step: 750/1407: Training loss = 0.25890, Training acc = 93.75%
# epoch 4/5, step: 1000/1407: Training loss = 0.25087, Training acc = 93.75%
# epoch 4/5, step: 1250/1407: Training loss = 0.31178, Training acc = 90.62%
#
# Epoch  4,                 Train: loss=0.268, accuracy=92.4%,                 Valid: loss=0.607, accuracy=81.9%
#
# epoch 5/5, step: 250/1407: Training loss = 0.15752, Training acc = 96.88%
# epoch 5/5, step: 500/1407: Training loss = 0.03398, Training acc = 100.00%
# epoch 5/5, step: 750/1407: Training loss = 0.23541, Training acc = 90.62%
# epoch 5/5, step: 1000/1407: Training loss = 0.10030, Training acc = 96.88%
# epoch 5/5, step: 1250/1407: Training loss = 0.15430, Training acc = 96.88%
#
# Epoch  5,                 Train: loss=0.161, accuracy=95.9%,                 Valid: loss=0.585, accuracy=82.7%

# %%
plot_loss_and_accuracy(train_loss, val_loss, train_acc, val_acc)

# %% [markdown]
# ## Densenet-121

# %% [markdown]
# ### CIFAR-10

# %%
dense121_10, train_loss, val_loss, train_acc, val_acc = train(dense121_10, train_loader_10, val_loader_10)
# Out:
# epoch 1/5, step: 250/1407: Training loss = 0.43499, Training acc = 75.00%
# epoch 1/5, step: 500/1407: Training loss = 0.22566, Training acc = 90.62%
# epoch 1/5, step: 750/1407: Training loss = 0.50070, Training acc = 87.50%
# epoch 1/5, step: 1000/1407: Training loss = 0.09731, Training acc = 93.75%
# epoch 1/5, step: 1250/1407: Training loss = 0.21599, Training acc = 90.62%
#
# Epoch  1,                 Train: loss=0.358, accuracy=88.4%,                 Valid: loss=0.152, accuracy=95.1%
#
# epoch 2/5, step: 250/1407: Training loss = 0.04944, Training acc = 96.88%
# epoch 2/5, step: 500/1407: Training loss = 0.01688, Training acc = 100.00%
# epoch 2/5, step: 750/1407: Training loss = 0.23655, Training acc = 90.62%
# epoch 2/5, step: 1000/1407: Training loss = 0.11897, Training acc = 90.62%
# epoch 2/5, step: 1250/1407: Training loss = 0.18187, Training acc = 96.88%
#
# Epoch  2,                 Train: loss=0.120, accuracy=96.1%,                 Valid: loss=0.127, accuracy=95.9%
#
# epoch 3/5, step: 250/1407: Training loss = 0.08665, Training acc = 96.88%
# epoch 3/5, step: 500/1407: Training loss = 0.07921, Training acc = 96.88%
# epoch 3/5, step: 750/1407: Training loss = 0.06688, Training acc = 96.88%
# epoch 3/5, step: 1000/1407: Training loss = 0.23730, Training acc = 93.75%
# epoch 3/5, step: 1250/1407: Training loss = 0.07698, Training acc = 96.88%
#
# Epoch  3,                 Train: loss=0.068, accuracy=97.9%,                 Valid: loss=0.116, accuracy=96.4%
#
# epoch 4/5, step: 250/1407: Training loss = 0.00451, Training acc = 100.00%
# epoch 4/5, step: 500/1407: Training loss = 0.31467, Training acc = 90.62%
# epoch 4/5, step: 750/1407: Training loss = 0.01089, Training acc = 100.00%
# epoch 4/5, step: 1000/1407: Training loss = 0.00607, Training acc = 100.00%
# epoch 4/5, step: 1250/1407: Training loss = 0.01819, Training acc = 100.00%
#
# Epoch  4,                 Train: loss=0.038, accuracy=98.8%,                 Valid: loss=0.119, accuracy=96.0%
#
# epoch 5/5, step: 250/1407: Training loss = 0.01183, Training acc = 100.00%
# epoch 5/5, step: 500/1407: Training loss = 0.03858, Training acc = 96.88%
# epoch 5/5, step: 750/1407: Training loss = 0.02880, Training acc = 100.00%
# epoch 5/5, step: 1000/1407: Training loss = 0.02673, Training acc = 100.00%
# epoch 5/5, step: 1250/1407: Training loss = 0.05648, Training acc = 96.88%
#
# Epoch  5,                 Train: loss=0.027, accuracy=99.2%,                 Valid: loss=0.132, accuracy=96.2%

# %%
plot_loss_and_accuracy(train_loss, val_loss, train_acc, val_acc)

# %% [markdown]
# ### CIFAR-100

# %%
dense121_100, train_loss, val_loss, train_acc, val_acc = train(dense121_100, train_loader_100, val_loader_100)
# Out:
# epoch 1/5, step: 250/1407: Training loss = 2.96241, Training acc = 25.00%
# epoch 1/5, step: 500/1407: Training loss = 1.64461, Training acc = 65.62%
# epoch 1/5, step: 750/1407: Training loss = 1.34423, Training acc = 68.75%
# epoch 1/5, step: 1000/1407: Training loss = 1.12441, Training acc = 71.88%
# epoch 1/5, step: 1250/1407: Training loss = 1.22447, Training acc = 68.75%
#
# Epoch  1,                 Train: loss=1.879, accuracy=55.3%,                 Valid: loss=0.857, accuracy=75.2%
#
# epoch 2/5, step: 250/1407: Training loss = 1.03805, Training acc = 75.00%
# epoch 2/5, step: 500/1407: Training loss = 0.59572, Training acc = 75.00%
# epoch 2/5, step: 750/1407: Training loss = 0.60054, Training acc = 87.50%
# epoch 2/5, step: 1000/1407: Training loss = 1.15554, Training acc = 68.75%
# epoch 2/5, step: 1250/1407: Training loss = 0.57089, Training acc = 87.50%
#
# Epoch  2,                 Train: loss=0.769, accuracy=78.2%,                 Valid: loss=0.687, accuracy=79.5%
#
# epoch 3/5, step: 250/1407: Training loss = 0.33299, Training acc = 90.62%
# epoch 3/5, step: 500/1407: Training loss = 0.60941, Training acc = 81.25%
# epoch 3/5, step: 750/1407: Training loss = 0.53548, Training acc = 87.50%
# epoch 3/5, step: 1000/1407: Training loss = 0.96232, Training acc = 78.12%
# epoch 3/5, step: 1250/1407: Training loss = 0.70988, Training acc = 90.62%
#
# Epoch  3,                 Train: loss=0.527, accuracy=84.6%,                 Valid: loss=0.630, accuracy=81.1%
#
# epoch 4/5, step: 250/1407: Training loss = 0.49171, Training acc = 84.38%
# epoch 4/5, step: 500/1407: Training loss = 0.40181, Training acc = 93.75%
# epoch 4/5, step: 750/1407: Training loss = 0.30592, Training acc = 90.62%
# epoch 4/5, step: 1000/1407: Training loss = 0.32820, Training acc = 90.62%
# epoch 4/5, step: 1250/1407: Training loss = 0.39566, Training acc = 90.62%
#
# Epoch  4,                 Train: loss=0.374, accuracy=89.2%,                 Valid: loss=0.606, accuracy=81.9%
#
# epoch 5/5, step: 250/1407: Training loss = 0.34152, Training acc = 90.62%
# epoch 5/5, step: 500/1407: Training loss = 0.22041, Training acc = 90.62%
# epoch 5/5, step: 750/1407: Training loss = 0.33458, Training acc = 90.62%
# epoch 5/5, step: 1000/1407: Training loss = 0.22474, Training acc = 93.75%
# epoch 5/5, step: 1250/1407: Training loss = 0.45800, Training acc = 87.50%
#
# Epoch  5,                 Train: loss=0.265, accuracy=92.5%,                 Valid: loss=0.617, accuracy=82.0%

# %%
plot_loss_and_accuracy(train_loss, val_loss, train_acc, val_acc)

# %% [markdown]
# # Evaluate the models

# %%
# Define the CIFAR-10 class names
cifar10_class_names = [
    'airplane', 'automobile', 'bird', 'cat', 'deer', 
    'dog', 'frog', 'horse', 'ship', 'truck'
]

# %%
from sklearn.metrics import classification_report
def evaluate(model, test_dataloader):
  with torch.no_grad():
      number_corrects = 0
      number_samples = 0
      y_predicted_total = []
      y_total = []
      for i, (test_images_set , test_labels_set) in enumerate(test_dataloader):
          test_images_set = test_images_set.to(device)
          test_labels_set = test_labels_set.to(device)
      
          y_predicted = model(test_images_set)
          labels_predicted = y_predicted.argmax(axis = 1)
          number_corrects += (labels_predicted==test_labels_set).sum().item()
          number_samples += test_labels_set.size(0)
          y_predicted_total.extend(labels_predicted.tolist())
          y_total.extend(test_labels_set.tolist())
      print(f'Overall accuracy {(number_corrects / number_samples)*100}%')
      print(classification_report(y_total, y_predicted_total))

      return y_total, y_predicted_total

# %%
labels, preds = evaluate(vgg16_10, test_loader_10)
# Out:
# Overall accuracy 92.12%
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      1000
#            1       0.98      0.94      0.96      1000
#            2       0.90      0.91      0.91      1000
#            3       0.86      0.83      0.84      1000
#            4       0.88      0.94      0.91      1000
#            5       0.94      0.82      0.88      1000
#            6       0.87      0.97      0.92      1000
#            7       0.96      0.92      0.94      1000
#            8       0.95      0.96      0.96      1000
#            9       0.95      0.97      0.96      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(labels, preds))

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(confusion_matrix_df, annot=True, cmap="Blues", fmt='g', ax=ax)

# set axis labels
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')

# set tick labels to be more readable
ax.xaxis.set_ticklabels(cifar10_class_names, rotation=90)
ax.yaxis.set_ticklabels(cifar10_class_names, rotation=0)

plt.show()

# %%
labels, preds = evaluate(vgg16_100, test_loader_100)
# Out:
# Overall accuracy 73.72%
#               precision    recall  f1-score   support
#
#            0       0.95      0.75      0.84       100
#            1       0.89      0.85      0.87       100
#            2       0.67      0.68      0.68       100
#            3       0.69      0.66      0.67       100
#            4       0.40      0.67      0.50       100
#            5       0.74      0.73      0.74       100
#            6       0.80      0.85      0.83       100
#            7       0.85      0.75      0.80       100
#            8       0.93      0.86      0.90       100
#            9       0.94      0.80      0.86       100
#           10       0.65      0.68      0.66       100
#           11       0.60      0.39      0.47       100
#           12       0.77      0.81      0.79       100
#           13       0.67      0.65      0.66       100
#           14       0.93      0.65      0.76       100
#           15       0.76      0.80      0.78       100
#           16       0.72      0.86      0.79       100
#           17       0.92      0.81      0.86       100
#           18       0.64      0.70      0.67       100
#           19       0.74      0.67      0.70       100
#           20       0.89      0.89      0.89       100
#           21       0.87      0.87      0.87       100
#           22       0.93      0.70      0.80       100
#           23       0.85      0.73      0.78       100
#           24       0.80      0.87      0.83       100
#           25       0.67      0.66      0.67       100
#           26       0.66      0.69      0.68       100
#           27       0.48      0.77      0.59       100
#           28       0.89      0.74      0.81       100
#           29       0.55      0.86      0.67       100
#           30       0.63      0.71      0.67       100
#           31       0.87      0.61      0.72       100
#           32       0.75      0.65      0.70       100
#           33       0.75      0.61      0.67       100
#           34       0.81      0.80      0.80       100
#           35       0.59      0.40      0.48       100
#           36       0.79      0.84      0.81       100
#           37       0.84      0.78      0.81       100
#           38       0.69      0.67      0.68       100
#           39       0.93      0.85      0.89       100
#           40       0.72      0.66      0.69       100
#           41       0.88      0.92      0.90       100
#           42       0.77      0.70      0.73       100
#           43       0.69      0.83      0.75       100
#           44       0.62      0.50      0.55       100
#           45       0.68      0.60      0.64       100
#           46       0.47      0.65      0.55       100
#           47       0.55      0.62      0.58       100
#           48       0.93      0.93      0.93       100
#           49       0.80      0.85      0.83       100
#           50       0.64      0.54      0.59       100
#           51       0.71      0.85      0.77       100
#           52       0.50      0.76      0.60       100
#           53       0.73      0.97      0.83       100
#           54       0.94      0.73      0.82       100
#           55       0.48      0.60      0.54       100
#           56       0.96      0.70      0.81       100
#           57       0.85      0.78      0.81       100
#           58       0.85      0.93      0.89       100
#           59       0.54      0.61      0.57       100
#           60       0.87      0.81      0.84       100
#           61       0.79      0.71      0.75       100
#           62       0.72      0.73      0.72       100
#           63       0.72      0.58      0.64       100
#           64       0.68      0.57      0.62       100
#           65       0.70      0.67      0.68       100
#           66       0.84      0.72      0.77       100
#           67       0.67      0.72      0.70       100
#           68       0.90      0.90      0.90       100
#           69       0.87      0.77      0.81       100
#           70       0.65      0.90      0.76       100
#           71       0.64      0.95      0.77       100
#           72       0.59      0.44      0.50       100
#           73       0.76      0.56      0.64       100
#           74       0.68      0.50      0.57       100
#           75       0.95      0.89      0.92       100
#           76       0.81      0.90      0.85       100
#           77       0.87      0.73      0.79       100
#           78       0.72      0.71      0.72       100
#           79       0.86      0.75      0.80       100
#           80       0.62      0.61      0.61       100
#           81       0.78      0.59      0.67       100
#           82       0.95      0.91      0.93       100
#           83       0.78      0.69      0.73       100
#           84       0.68      0.81      0.74       100
#           85       0.81      0.81      0.81       100
#           86       0.83      0.68      0.75       100
#           87       0.83      0.87      0.85       100
#           88       0.79      0.88      0.83       100
#           89       0.79      0.92      0.85       100
#           90       0.74      0.81      0.78       100
#           91       0.80      0.81      0.81       100
#           92       0.64      0.59      0.61       100
#           93       0.64      0.74      0.69       100
#           94       0.91      0.95      0.93       100
#           95       0.70      0.85      0.77       100
#           96       0.70      0.42      0.53       100
#           97       0.65      0.84      0.73       100
#           98       0.53      0.63      0.57       100
#           99       0.82      0.75      0.79       100
#
#     accuracy                           0.74     10000
#    macro avg       0.75      0.74      0.74     10000
# weighted avg       0.75      0.74      0.74     10000

# %%
labels, preds = evaluate(effnet_v2_10, test_loader_10)
# Out:
# Overall accuracy 97.71%
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1000
#            1       0.98      0.98      0.98      1000
#            2       0.98      0.97      0.98      1000
#            3       0.94      0.95      0.95      1000
#            4       0.97      0.98      0.98      1000
#            5       0.96      0.95      0.96      1000
#            6       0.99      0.99      0.99      1000
#            7       0.99      0.98      0.98      1000
#            8       0.99      0.99      0.99      1000
#            9       0.98      0.98      0.98      1000
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(labels, preds))

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(confusion_matrix_df, annot=True, cmap="Blues", fmt='g', ax=ax)

# set axis labels
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')

# set tick labels to be more readable
ax.xaxis.set_ticklabels(cifar10_class_names, rotation=90)
ax.yaxis.set_ticklabels(cifar10_class_names, rotation=0)

plt.show()

# %%
labels, preds = evaluate(effnet_v2_100, test_loader_100)
# Out:
# Overall accuracy 87.58%
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       100
#            1       0.92      0.93      0.93       100
#            2       0.74      0.84      0.79       100
#            3       0.95      0.86      0.90       100
#            4       0.84      0.79      0.81       100
#            5       0.88      0.89      0.89       100
#            6       0.95      0.94      0.94       100
#            7       0.95      0.90      0.92       100
#            8       0.96      0.94      0.95       100
#            9       0.95      0.94      0.94       100
#           10       0.73      0.79      0.76       100
#           11       0.62      0.62      0.62       100
#           12       0.97      0.90      0.93       100
#           13       0.91      0.86      0.88       100
#           14       0.95      0.90      0.92       100
#           15       0.93      0.92      0.92       100
#           16       0.92      0.91      0.91       100
#           17       0.93      0.94      0.94       100
#           18       0.96      0.86      0.91       100
#           19       0.88      0.88      0.88       100
#           20       0.90      0.94      0.92       100
#           21       0.97      0.98      0.98       100
#           22       0.98      0.94      0.96       100
#           23       0.94      0.87      0.90       100
#           24       0.91      0.96      0.93       100
#           25       0.88      0.79      0.83       100
#           26       0.87      0.89      0.88       100
#           27       0.92      0.88      0.90       100
#           28       0.87      0.90      0.89       100
#           29       0.92      0.89      0.90       100
#           30       0.87      0.76      0.81       100
#           31       0.96      0.95      0.95       100
#           32       0.73      0.85      0.78       100
#           33       0.82      0.74      0.78       100
#           34       0.89      0.93      0.91       100
#           35       0.81      0.57      0.67       100
#           36       0.90      0.94      0.92       100
#           37       0.90      0.87      0.88       100
#           38       0.89      0.91      0.90       100
#           39       0.96      0.95      0.95       100
#           40       0.95      0.87      0.91       100
#           41       0.96      0.99      0.98       100
#           42       0.85      0.92      0.88       100
#           43       0.93      0.94      0.94       100
#           44       0.85      0.95      0.90       100
#           45       0.84      0.87      0.85       100
#           46       0.60      0.78      0.68       100
#           47       0.81      0.44      0.57       100
#           48       0.93      0.97      0.95       100
#           49       0.86      0.93      0.89       100
#           50       0.74      0.77      0.75       100
#           51       0.92      0.93      0.93       100
#           52       0.66      0.69      0.67       100
#           53       0.95      0.97      0.96       100
#           54       0.90      0.88      0.89       100
#           55       0.68      0.82      0.75       100
#           56       0.95      0.92      0.93       100
#           57       0.93      0.86      0.90       100
#           58       0.96      0.97      0.97       100
#           59       0.70      0.73      0.71       100
#           60       0.82      0.92      0.87       100
#           61       0.91      0.74      0.82       100
#           62       0.85      0.82      0.84       100
#           63       0.92      0.82      0.87       100
#           64       0.90      0.75      0.82       100
#           65       0.74      0.93      0.82       100
#           66       0.93      0.90      0.91       100
#           67       0.86      0.90      0.88       100
#           68       0.90      0.95      0.92       100
#           69       0.94      0.92      0.93       100
#           70       0.86      0.92      0.89       100
#           71       0.92      0.88      0.90       100
#           72       0.79      0.75      0.77       100
#           73       0.85      0.91      0.88       100
#           74       0.64      0.69      0.67       100
#           75       0.92      0.98      0.95       100
#           76       0.98      0.96      0.97       100
#           77       0.91      0.94      0.93       100
#           78       0.91      0.83      0.87       100
#           79       0.94      0.94      0.94       100
#           80       0.88      0.82      0.85       100
#           81       0.83      0.91      0.87       100
#           82       0.98      0.97      0.97       100
#           83       0.97      0.87      0.92       100
#           84       0.91      0.87      0.89       100
#           85       0.97      0.98      0.98       100
#           86       0.92      0.91      0.91       100
#           87       0.95      0.94      0.94       100
#           88       0.96      0.87      0.91       100
#           89       0.93      1.00      0.96       100
#           90       0.91      0.90      0.90       100
#           91       0.97      0.89      0.93       100
#           92       0.80      0.79      0.79       100
#           93       0.95      0.94      0.94       100
#           94       0.98      0.94      0.96       100
#           95       0.83      0.86      0.84       100
#           96       0.58      0.79      0.67       100
#           97       0.96      0.93      0.94       100
#           98       0.73      0.72      0.73       100
#           99       0.85      0.92      0.88       100
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %%
labels, preds = evaluate(effnet_10, test_loader_10)
# Out:
# Overall accuracy 96.1%
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1000
#            1       0.97      0.98      0.97      1000
#            2       0.97      0.95      0.96      1000
#            3       0.92      0.91      0.92      1000
#            4       0.96      0.95      0.96      1000
#            5       0.92      0.94      0.93      1000
#            6       0.98      0.98      0.98      1000
#            7       0.97      0.98      0.97      1000
#            8       0.97      0.99      0.98      1000
#            9       0.97      0.97      0.97      1000
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(labels, preds))

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(confusion_matrix_df, annot=True, cmap="Blues", fmt='g', ax=ax)

# set axis labels
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')

# set tick labels to be more readable
ax.xaxis.set_ticklabels(cifar10_class_names, rotation=90)
ax.yaxis.set_ticklabels(cifar10_class_names, rotation=0)

plt.show()

# %%
labels, preds = evaluate(effnet_100, test_loader_100)
# Out:
# Overall accuracy 81.71000000000001%
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       100
#            1       0.95      0.87      0.91       100
#            2       0.68      0.75      0.71       100
#            3       0.73      0.80      0.76       100
#            4       0.67      0.69      0.68       100
#            5       0.77      0.80      0.78       100
#            6       0.93      0.83      0.88       100
#            7       0.89      0.82      0.85       100
#            8       0.95      0.92      0.93       100
#            9       0.92      0.90      0.91       100
#           10       0.71      0.72      0.71       100
#           11       0.54      0.49      0.52       100
#           12       0.89      0.87      0.88       100
#           13       0.78      0.77      0.77       100
#           14       0.89      0.86      0.87       100
#           15       0.82      0.87      0.84       100
#           16       0.86      0.89      0.88       100
#           17       0.94      0.90      0.92       100
#           18       0.84      0.86      0.85       100
#           19       0.92      0.83      0.87       100
#           20       0.91      0.91      0.91       100
#           21       0.86      0.96      0.91       100
#           22       0.89      0.91      0.90       100
#           23       0.80      0.85      0.83       100
#           24       0.83      0.91      0.87       100
#           25       0.80      0.69      0.74       100
#           26       0.87      0.76      0.81       100
#           27       0.74      0.75      0.74       100
#           28       0.87      0.87      0.87       100
#           29       0.87      0.77      0.81       100
#           30       0.67      0.80      0.73       100
#           31       0.92      0.86      0.89       100
#           32       0.71      0.75      0.73       100
#           33       0.79      0.63      0.70       100
#           34       0.93      0.76      0.84       100
#           35       0.73      0.53      0.61       100
#           36       0.88      0.90      0.89       100
#           37       0.91      0.83      0.87       100
#           38       0.78      0.79      0.79       100
#           39       0.91      0.94      0.93       100
#           40       0.85      0.80      0.82       100
#           41       0.92      0.93      0.93       100
#           42       0.78      0.84      0.81       100
#           43       0.91      0.86      0.89       100
#           44       0.82      0.84      0.83       100
#           45       0.80      0.76      0.78       100
#           46       0.57      0.67      0.61       100
#           47       0.67      0.71      0.69       100
#           48       0.91      0.96      0.93       100
#           49       0.87      0.90      0.89       100
#           50       0.65      0.65      0.65       100
#           51       0.81      0.92      0.86       100
#           52       0.58      0.80      0.67       100
#           53       0.91      0.95      0.93       100
#           54       0.82      0.89      0.86       100
#           55       0.59      0.72      0.65       100
#           56       0.90      0.93      0.92       100
#           57       0.87      0.86      0.86       100
#           58       0.95      0.92      0.93       100
#           59       0.83      0.52      0.64       100
#           60       0.82      0.82      0.82       100
#           61       0.84      0.75      0.79       100
#           62       0.80      0.77      0.79       100
#           63       0.77      0.79      0.78       100
#           64       0.71      0.70      0.71       100
#           65       0.72      0.81      0.76       100
#           66       0.79      0.89      0.84       100
#           67       0.70      0.79      0.74       100
#           68       0.87      0.97      0.92       100
#           69       0.87      0.89      0.88       100
#           70       0.80      0.78      0.79       100
#           71       0.74      0.92      0.82       100
#           72       0.62      0.50      0.55       100
#           73       0.73      0.68      0.70       100
#           74       0.62      0.63      0.63       100
#           75       0.90      0.94      0.92       100
#           76       0.91      0.92      0.92       100
#           77       0.87      0.89      0.88       100
#           78       0.83      0.83      0.83       100
#           79       0.85      0.89      0.87       100
#           80       0.77      0.72      0.74       100
#           81       0.76      0.83      0.79       100
#           82       0.93      0.94      0.94       100
#           83       0.91      0.81      0.86       100
#           84       0.89      0.79      0.84       100
#           85       0.90      0.95      0.93       100
#           86       0.84      0.86      0.85       100
#           87       0.94      0.94      0.94       100
#           88       0.93      0.78      0.85       100
#           89       0.90      0.92      0.91       100
#           90       0.86      0.90      0.88       100
#           91       0.86      0.88      0.87       100
#           92       0.77      0.66      0.71       100
#           93       0.77      0.79      0.78       100
#           94       0.94      0.97      0.96       100
#           95       0.83      0.68      0.75       100
#           96       0.72      0.64      0.68       100
#           97       0.91      0.92      0.92       100
#           98       0.65      0.66      0.65       100
#           99       0.88      0.89      0.89       100
#
#     accuracy                           0.82     10000
#    macro avg       0.82      0.82      0.82     10000
# weighted avg       0.82      0.82      0.82     10000

# %%
labels, preds = evaluate(res50_10, test_loader_10)
# Out:
# Overall accuracy 96.13000000000001%
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      1000
#            1       0.95      0.99      0.97      1000
#            2       0.98      0.93      0.96      1000
#            3       0.92      0.93      0.92      1000
#            4       0.96      0.96      0.96      1000
#            5       0.96      0.93      0.94      1000
#            6       0.95      0.99      0.97      1000
#            7       0.99      0.98      0.98      1000
#            8       0.98      0.98      0.98      1000
#            9       0.98      0.94      0.96      1000
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(labels, preds))

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(confusion_matrix_df, annot=True, cmap="Blues", fmt='g', ax=ax)

# set axis labels
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')

# set tick labels to be more readable
ax.xaxis.set_ticklabels(cifar10_class_names, rotation=90)
ax.yaxis.set_ticklabels(cifar10_class_names, rotation=0)

plt.show()

# %%
labels, preds = evaluate(res50_100, test_loader_100)
# Out:
# Overall accuracy 82.3%
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       100
#            1       0.92      0.89      0.90       100
#            2       0.83      0.64      0.72       100
#            3       0.82      0.70      0.76       100
#            4       0.75      0.79      0.77       100
#            5       0.89      0.82      0.85       100
#            6       0.91      0.86      0.88       100
#            7       0.91      0.85      0.88       100
#            8       0.97      0.95      0.96       100
#            9       0.94      0.93      0.93       100
#           10       0.77      0.61      0.68       100
#           11       0.56      0.58      0.57       100
#           12       0.90      0.85      0.88       100
#           13       0.89      0.74      0.81       100
#           14       0.87      0.83      0.85       100
#           15       0.83      0.90      0.86       100
#           16       0.87      0.90      0.89       100
#           17       0.90      0.88      0.89       100
#           18       0.90      0.79      0.84       100
#           19       0.84      0.82      0.83       100
#           20       0.89      0.90      0.90       100
#           21       0.92      0.95      0.94       100
#           22       0.87      0.93      0.90       100
#           23       0.91      0.89      0.90       100
#           24       0.86      0.93      0.89       100
#           25       0.82      0.75      0.79       100
#           26       0.70      0.80      0.74       100
#           27       0.79      0.74      0.76       100
#           28       0.84      0.87      0.85       100
#           29       0.84      0.82      0.83       100
#           30       0.75      0.79      0.77       100
#           31       0.90      0.83      0.86       100
#           32       0.76      0.72      0.74       100
#           33       0.72      0.65      0.68       100
#           34       0.87      0.91      0.89       100
#           35       0.68      0.63      0.66       100
#           36       0.91      0.79      0.84       100
#           37       0.81      0.88      0.85       100
#           38       0.74      0.84      0.79       100
#           39       0.95      0.90      0.92       100
#           40       0.81      0.86      0.83       100
#           41       0.92      0.96      0.94       100
#           42       0.90      0.79      0.84       100
#           43       0.92      0.86      0.89       100
#           44       0.82      0.76      0.79       100
#           45       0.77      0.73      0.75       100
#           46       0.66      0.71      0.69       100
#           47       0.65      0.58      0.61       100
#           48       0.91      0.96      0.94       100
#           49       0.82      0.95      0.88       100
#           50       0.65      0.64      0.64       100
#           51       0.90      0.87      0.88       100
#           52       0.70      0.56      0.62       100
#           53       0.90      0.95      0.93       100
#           54       0.83      0.87      0.85       100
#           55       0.64      0.63      0.63       100
#           56       0.96      0.88      0.92       100
#           57       0.85      0.88      0.86       100
#           58       0.97      0.98      0.98       100
#           59       0.60      0.75      0.66       100
#           60       0.84      0.92      0.88       100
#           61       0.80      0.74      0.77       100
#           62       0.90      0.70      0.79       100
#           63       0.80      0.77      0.79       100
#           64       0.78      0.62      0.69       100
#           65       0.69      0.90      0.78       100
#           66       0.82      0.89      0.86       100
#           67       0.80      0.77      0.79       100
#           68       0.95      0.94      0.94       100
#           69       0.85      0.87      0.86       100
#           70       0.81      0.87      0.84       100
#           71       0.86      0.80      0.83       100
#           72       0.56      0.66      0.61       100
#           73       0.70      0.81      0.75       100
#           74       0.61      0.66      0.63       100
#           75       0.93      0.93      0.93       100
#           76       0.89      0.93      0.91       100
#           77       0.87      0.85      0.86       100
#           78       0.77      0.89      0.82       100
#           79       0.84      0.90      0.87       100
#           80       0.80      0.78      0.79       100
#           81       0.78      0.90      0.83       100
#           82       0.96      0.94      0.95       100
#           83       0.88      0.74      0.80       100
#           84       0.84      0.81      0.83       100
#           85       0.93      0.89      0.91       100
#           86       0.87      0.88      0.88       100
#           87       0.88      0.95      0.91       100
#           88       0.86      0.83      0.85       100
#           89       0.93      0.92      0.92       100
#           90       0.89      0.88      0.88       100
#           91       0.89      0.88      0.88       100
#           92       0.65      0.80      0.71       100
#           93       0.78      0.83      0.81       100
#           94       0.92      0.98      0.95       100
#           95       0.79      0.77      0.78       100
#           96       0.58      0.69      0.63       100
#           97       0.97      0.88      0.92       100
#           98       0.64      0.76      0.69       100
#           99       0.88      0.82      0.85       100
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000

# %%
labels, preds = evaluate(dense121_10, test_loader_10)
# Out:
# Overall accuracy 96.44%
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1000
#            1       0.96      0.98      0.97      1000
#            2       0.97      0.96      0.96      1000
#            3       0.93      0.94      0.93      1000
#            4       0.96      0.97      0.96      1000
#            5       0.96      0.93      0.94      1000
#            6       0.98      0.99      0.98      1000
#            7       0.97      0.98      0.97      1000
#            8       0.96      0.98      0.97      1000
#            9       0.99      0.96      0.97      1000
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(labels, preds))

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(confusion_matrix_df, annot=True, cmap="Blues", fmt='g', ax=ax)

# set axis labels
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')

# set tick labels to be more readable
ax.xaxis.set_ticklabels(cifar10_class_names, rotation=90)
ax.yaxis.set_ticklabels(cifar10_class_names, rotation=0)

plt.show()

# %%
labels, preds = evaluate(dense121_100, test_loader_100)
# Out:
# Overall accuracy 82.08%
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       100
#            1       0.93      0.88      0.90       100
#            2       0.66      0.84      0.74       100
#            3       0.77      0.73      0.75       100
#            4       0.69      0.76      0.72       100
#            5       0.88      0.75      0.81       100
#            6       0.95      0.88      0.91       100
#            7       0.90      0.79      0.84       100
#            8       0.96      0.95      0.95       100
#            9       0.90      0.96      0.93       100
#           10       0.71      0.68      0.69       100
#           11       0.65      0.59      0.62       100
#           12       0.86      0.84      0.85       100
#           13       0.85      0.77      0.81       100
#           14       0.95      0.79      0.86       100
#           15       0.85      0.86      0.86       100
#           16       0.93      0.86      0.90       100
#           17       0.91      0.95      0.93       100
#           18       0.86      0.84      0.85       100
#           19       0.85      0.82      0.83       100
#           20       0.91      0.89      0.90       100
#           21       0.83      0.96      0.89       100
#           22       0.86      0.91      0.88       100
#           23       0.82      0.90      0.86       100
#           24       0.92      0.88      0.90       100
#           25       0.74      0.81      0.78       100
#           26       0.85      0.79      0.82       100
#           27       0.69      0.83      0.75       100
#           28       0.93      0.82      0.87       100
#           29       0.90      0.81      0.85       100
#           30       0.72      0.78      0.75       100
#           31       0.89      0.78      0.83       100
#           32       0.84      0.73      0.78       100
#           33       0.73      0.78      0.75       100
#           34       0.90      0.87      0.88       100
#           35       0.65      0.53      0.59       100
#           36       0.90      0.89      0.89       100
#           37       0.94      0.83      0.88       100
#           38       0.91      0.82      0.86       100
#           39       0.96      0.92      0.94       100
#           40       0.70      0.86      0.77       100
#           41       0.94      0.91      0.92       100
#           42       0.80      0.76      0.78       100
#           43       0.90      0.90      0.90       100
#           44       0.74      0.81      0.78       100
#           45       0.76      0.77      0.77       100
#           46       0.73      0.57      0.64       100
#           47       0.74      0.54      0.62       100
#           48       0.95      0.92      0.93       100
#           49       0.86      0.89      0.87       100
#           50       0.73      0.61      0.67       100
#           51       0.86      0.87      0.87       100
#           52       0.54      0.84      0.66       100
#           53       0.88      0.95      0.91       100
#           54       0.82      0.90      0.86       100
#           55       0.59      0.61      0.60       100
#           56       0.96      0.88      0.92       100
#           57       0.91      0.83      0.87       100
#           58       0.93      0.99      0.96       100
#           59       0.79      0.55      0.65       100
#           60       0.91      0.84      0.87       100
#           61       0.78      0.76      0.77       100
#           62       0.68      0.87      0.76       100
#           63       0.72      0.83      0.77       100
#           64       0.77      0.68      0.72       100
#           65       0.71      0.84      0.77       100
#           66       0.87      0.87      0.87       100
#           67       0.76      0.80      0.78       100
#           68       0.91      0.94      0.93       100
#           69       0.88      0.86      0.87       100
#           70       0.78      0.86      0.82       100
#           71       0.79      0.85      0.82       100
#           72       0.62      0.61      0.61       100
#           73       0.68      0.83      0.75       100
#           74       0.70      0.62      0.66       100
#           75       0.84      0.97      0.90       100
#           76       0.90      0.92      0.91       100
#           77       0.94      0.82      0.88       100
#           78       0.83      0.79      0.81       100
#           79       0.85      0.92      0.88       100
#           80       0.80      0.78      0.79       100
#           81       0.76      0.86      0.81       100
#           82       0.97      0.94      0.95       100
#           83       0.81      0.86      0.83       100
#           84       0.86      0.83      0.84       100
#           85       0.89      0.93      0.91       100
#           86       0.85      0.85      0.85       100
#           87       0.85      0.93      0.89       100
#           88       0.77      0.92      0.84       100
#           89       0.91      0.95      0.93       100
#           90       0.92      0.78      0.84       100
#           91       0.95      0.88      0.91       100
#           92       0.84      0.61      0.71       100
#           93       0.84      0.81      0.83       100
#           94       0.95      0.94      0.94       100
#           95       0.82      0.75      0.78       100
#           96       0.61      0.62      0.62       100
#           97       0.86      0.89      0.87       100
#           98       0.62      0.71      0.66       100
#           99       0.86      0.80      0.83       100
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000
